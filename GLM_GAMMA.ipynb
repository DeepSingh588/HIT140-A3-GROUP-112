# %%
# --- MEMBER 4: KARAMPAL SINGH: Investigation B (GLM Gamma) ---

# Problem: Diagnostic showed missing cell data ('Rat Absent' periods), failing Two-Way ANOVA.
print("Problem: ANOVA failed due to data sparsity (missing Rat Absent condition).")
