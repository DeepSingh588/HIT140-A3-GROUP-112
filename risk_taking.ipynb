# %%
# --- MEMBER 3: MEHAKPREET SINGH: Investigation A (Logistic Risk-Taking) ---

# Problem: Incorrectly used OLS for binary 'risk' variable, violating OLS assumptions.
print("Problem: OLS was the wrong choice; needed a model for binary outcomes.")
