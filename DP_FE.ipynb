# %%
# --- MEMBER 1: JAGDEEP SINGH: Data Preparation & Feature Engineering ---

# Problem: Time format failure on initial merge.
print("Problem: Initial merge failed due to datetime format mismatch (DD/MM/YYYY).")
