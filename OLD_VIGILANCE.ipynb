# %%
# --- MEMBER 2: KARANJOT SINGH:  A (OLS Vigilance) ---

# Problem: Simple OLS model Investigationfailed to control for the confounding variable 'food_availability'.
print("Problem: Simple model was scientifically flawed as it did not control for competition.")
